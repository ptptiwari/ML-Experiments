# %% [markdown]
# <a href="https://colab.research.google.com/github/ptptiwari/ML-Experiments/blob/main/CustomerSegment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Task
# Load the dataset "My Drive/customer_data.csv" from Google Drive into a dataframe and display the first 5 rows and the columns and their types.

# %% [markdown]
# ## Mount google drive
#
# ### Subtask:
# Mount Google Drive to access files stored there.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to access the dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the data from the specified file path in Google Drive into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the dataset from the specified file path into a pandas DataFrame and store it in a variable named `df`.

# %%
file_path = '/content/customer_data.csv'
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (2240, 29)

# %%
df.describe().T
# Out:
#                       count          mean           std     min       25%  \
# ID                   2240.0   5592.159821   3246.662198     0.0   2828.25
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2216.0  52247.251354  25173.076661  1730.0  35303.00
# Kidhome              2240.0      0.444196      0.538398     0.0      0.00
# Teenhome             2240.0      0.506250      0.544538     0.0      0.00
# Recency              2240.0     49.109375     28.962453     0.0     24.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# ...

# %%
for col in df.columns:
    temp = df[col].isnull().sum()
    if temp > 0:
        print(f'Column {col} contains {temp} null values.')
# Out:
# Column Income contains 24 null values.

# %%
df = df.dropna()
print("Total values in the dataset after removing the null values:", len(df))
# Out:
# Total values in the dataset after removing the null values: 2216

# %%
df.nunique()
# Out:
# ID                     2216
# Year_Birth               59
# Education                 5
# Marital_Status            8
# Income                 1974
# Kidhome                   3
# Teenhome                  3
# Dt_Customer             662
# Recency                 100
# MntWines                776
# MntFruits               158
# MntMeatProducts         554
# MntFishProducts         182
# MntSweetProducts        176
# MntGoldProds            212
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# AcceptedCmp3              2
# AcceptedCmp4              2
# AcceptedCmp5              2
# AcceptedCmp1              2
# AcceptedCmp2              2
# Complain                  2
# Z_CostContact             1
# Z_Revenue                 1
# Response                  2
# dtype: int64

# %%
floats, objects = [], []
for col in df.columns:
    if df[col].dtype == object:
        objects.append(col)
    elif df[col].dtype == float:
        floats.append(col)

print(objects)
print(floats)
# Out:
# ['Education', 'Marital_Status', 'Dt_Customer']
# ['Income']

# %%
plt.subplots(figsize=(15, 10))
for i, col in enumerate(objects):
    plt.subplot(2, 2, i + 1)
    sb.countplot(df[col])
plt.show()

# %%
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     857
# Together    573
# Single      471
# Divorced    232
# Widow        76
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == object:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])

# %%
plt.figure(figsize=(15, 15))
sb.heatmap(df.corr() > 0.8, annot=True, cbar=False)
plt.show()

# %%
scaler = StandardScaler()
data = scaler.fit_transform(df)

# %%
from sklearn.manifold import TSNE
model = TSNE(n_components=2, random_state=0)
tsne_data = model.fit_transform(df)
plt.figure(figsize=(7, 7))
plt.scatter(tsne_data[:, 0], tsne_data[:, 1])
plt.show()

# %% [markdown]
# **Reasoning**:
# The previous attempt to load the file failed because the file path was incorrect. I need to provide the correct file path to load the data.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Multiple attempts were made to load the `customer_data.csv` file from various paths within Google Drive (`/content/drive/Shareddrives/customer_data.csv`, `/content/drive/MyDrive/customer_data.csv`, and `/content/drive/MyDrive/data/customer_data.csv`).
# *   All attempts to load the data resulted in a `FileNotFoundError`, indicating that the file was not present at the specified locations.
# *   As a result, the DataFrame `df` could not be created, and the subsequent steps to display the data and its information failed.
#
# ### Insights or Next Steps
#
# *   Verify the exact location and spelling of the `customer_data.csv` file within Google Drive.
# *   Ensure that the Google Drive is correctly mounted and accessible from the Colab environment.
